# %% [markdown]
# <a href="https://colab.research.google.com/github/norayehia/Devices-Price-Classification-System/blob/main/Apredict_10_rowsi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from joblib import load

# %%
# Load the saved model
loaded_model = load('/content/drive/MyDrive/help/hiring/pyproject/random_forest_model.joblib')

# %%
dft = pd.read_csv("/content/drive/MyDrive/help/hiring/pyproject/test.csv")
dft=dft.drop(['id'], axis=1)
# Select the first 10 rows
dft = dft.dropna()
test_data = dft.head(10)


# Assuming your test data has the same features as the training data
# Replace 'features' with the actual features used in your model
#X_test = test_data[features]
test_data
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0           1043     1          1.8         1  14       0           5    0.1
# 1            841     1          0.5         1   4       1          61    0.8
# 2           1807     1          2.8         0   1       0          27    0.9
# 3           1546     0          0.5         1  18       1          25    0.5
# 4           1434     0          1.4         0  11       1          49    0.5
# 5           1464     1          2.9         1   5       1          50    0.8
# 6           1718     0          2.4         0   1       0          47    1.0
# 7            833     0          2.4         1   0       0          62    0.8
# 8           1111     1          2.9         1   9       1          25    0.6
# 9           1520     0          0.5         0   1       0          25    0.5
#
#    mobile_wt  n_cores  pc  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# ...

# %%
# Make predictions
predictions = loaded_model.predict(test_data)

print("Predictions for the first 10 rows of the test data:")
print(predictions)
# Out:
# Predictions for the first 10 rows of the test data:
# [3 3 2 3 1 3 3 1 3 0]

# %% [markdown]
# predict 10 rows

# %%
prediction_labels = {
    0: 'low cost',
    1: 'medium cost',
    2: 'high cost',
    3: 'very high cost'
}

# Print predictions
print("Predictions for the first 10 rows of the test data:")
for prediction in predictions:
    print(prediction_labels[prediction])
# Out:
# Predictions for the first 10 rows of the test data:
# very high cost
# very high cost
# high cost
# very high cost
# medium cost
# very high cost
# very high cost
# medium cost
# very high cost
# low cost

# %% [markdown]
# =============================================API
